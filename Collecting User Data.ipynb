# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (1.2.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)

# %%
import tweepy #used to work with Twitter's API
import webbrowser
import time
import pandas as pd

# %%
consumer_key = "jzn0NU9EviCRRbONbUXX9a8VN" #pulled from developer account for Twitter
consumer_secret = "ULsKu9BjBPmZ3yY5NdS6EXUhGBNWKUWxtwKqFktBeqsOq1Y3ZQ" #pulled from developer account for Twitter
#key and secret is generated by Twitter developer account

# %%
callback_uri = 'oob'#url

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri) #authorization to pull data from Twitter's API
redirect_url = auth.get_authorization_url() 
print(redirect_url)
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=MNwZSQAAAAABQdBPAAABehdiqFo

# %%
webbrowser.open(redirect_url)
# Out:
# True

# %%
user_pint_input = input("What's the pin value? ") #this is based upon Twitter Developer account
#Pin is generated new everytime this cell is run
# Out:
# What's the pin value? 3525247

# %%
auth.get_access_token(user_pint_input)
# Out:
# ('781482721-6928Gtnj95bK82PW3fYDxHFvU5T4l3SPI4VVF1X2',
#  'fTxclLJ4oxEmqshRhSbBibGoUiNq1l6941C0VyREdTf41')

# %%
print(auth.access_token, auth.access_token_secret)
# Out:
# 781482721-6928Gtnj95bK82PW3fYDxHFvU5T4l3SPI4VVF1X2 fTxclLJ4oxEmqshRhSbBibGoUiNq1l6941C0VyREdTf41

# %%
api = tweepy.API(auth)

# %%
def extract_timeline_as_df(timeline_list):
    columns = set()
    allowed_types = [str, int]
    tweets_data = []
    for status in timeline_list:
        status_dict = dict(vars(status))
        keys = status_dict.keys()
        single_tweet_data = {"user": status.user.screen_name, "author": status.author.screen_name}
        for k in keys:
            try:
                v_type = type(status_dict[k])
            except:
                v_type = None
            if v_type != None:
                if v_type in allowed_types:
                    single_tweet_data[k] = status_dict[k]
                    columns.add(k)
        tweets_data.append(single_tweet_data)


    header_cols = list(columns)
    header_cols.append("user")
    header_cols.append('author')
    df = pd.DataFrame(tweets_data, columns=header_cols)
    return df

# %%
screen_name = "code" #pulls data from Visual Studio Code's twitter page https://twitter.com/code
user = api.get_user(screen_name)
user_timeline = user.timeline() #recent tweets are pulled in the spreadsheet
df1 = extract_timeline_as_df(user_timeline)
df1.head()
# Out:
#    in_reply_to_user_id in_reply_to_screen_name     source  \
# 0                  NaN                     NaN     Buffer
# 1                  NaN                     NaN  TweetDeck
# 2                  NaN                     NaN     Buffer
# 3                  NaN                     NaN     Buffer
# 4                  NaN                     NaN     Buffer
#
#                                                 text               id_str  \
# 0  RT @mattbierner: Today's @code setting: sugges...  1405284556693856256
# 1  RT @yaojinyang: Welcome to May’s updates on VS...  1405256932726697991
# 2  RT @freeCodeCamp: Have you heard? You can now ...  1405210223627935750
# 3  RT @mattbierner: Today's @code tip: terminal t...  1405190182966640641
# 4  RT @DynamicWebPaige: Have you ever tried @code...  1404923676605157376
#
#    favorite_count in_reply_to_status_id_str  quoted_status_id lang  \
# 0               0                       NaN               NaN   en
# 1               0                       NaN               NaN   en
# 2               0                       NaN               NaN   en
# 3               0                       NaN               NaN   en
# 4               0                       NaN      1.404796e+18   en
#
#   quoted_status_id_str                                    source_url  \
# 0                  NaN                            https://buffer.com
# 1                  NaN  https://about.twitter.com/products/tweetdeck
# 2                  NaN                            https://buffer.com
# 3                  NaN                            https://buffer.com
# 4  1404796393181614086                            https://buffer.com
#
#    retweet_count in_reply_to_user_id_str  in_reply_to_status_id  \
# 0             12                     NaN                    NaN
# 1             27                     NaN                    NaN
# 2             83                     NaN                    NaN
# 3             19                     NaN                    NaN
# 4             86                     NaN                    NaN
#
#                     id  user author
# 0  1405284556693856256  code   code
# 1  1405256932726697991  code   code
# 2  1405210223627935750  code   code
# 3  1405190182966640641  code   code
# 4  1404923676605157376  code   code

# %%
df1.to_csv('tweetspreadsheet.csv', index=False)

# %%
df1_saved_file = pd.read_csv('tweetspreadsheet.csv')
df1_saved_file
# Out:
#     in_reply_to_user_id in_reply_to_screen_name               source  \
# 0                   NaN                     NaN               Buffer
# 1                   NaN                     NaN            TweetDeck
# 2                   NaN                     NaN               Buffer
# 3                   NaN                     NaN               Buffer
# 4                   NaN                     NaN               Buffer
# 5            28189006.0              marcduiker            TweetDeck
# 6                   NaN                     NaN               Buffer
# 7                   NaN                     NaN               Buffer
# 8                   NaN                     NaN               Buffer
# 9             6619162.0                    n1k0            TweetDeck
# 10                  NaN                     NaN            TweetDeck
# 11                  NaN                     NaN               Buffer
# 12                  NaN                     NaN               Buffer
# 13                  NaN                     NaN            TweetDeck
# 14                  NaN                     NaN               Buffer
# 15           12514012.0                 olafurw            TweetDeck
# 16           12514012.0                 olafurw            TweetDeck
# 17                  NaN                     NaN            TweetDeck
# 18                  NaN                     NaN  Sprinklr Publishing
# 19           17621534.0             theGoldyMan            TweetDeck
#
#                                                  text               id_str  \
# 0   RT @mattbierner: Today's @code setting: sugges...  1405284556693856256
# 1   RT @yaojinyang: Welcome to May’s updates on VS...  1405256932726697991
# 2   RT @freeCodeCamp: Have you heard? You can now ...  1405210223627935750
# 3   RT @mattbierner: Today's @code tip: terminal t...  1405190182966640641
# 4   RT @DynamicWebPaige: Have you ever tried @code...  1404923676605157376
# 5   @marcduiker @suzmue CC: @anthonypjshaw Gopher ...  1404884676305588225
# 6   RT @pythonvscode: The June release for the #ju...  1404865795268780038
# 7   💬 What's so special about #Golang? And how can...  1404827556411588615
# 8   RT @GarvNanwani: @code tip -\n\nNormally when ...  1404559526431543301
# 9                     @n1k0 👀 https://t.co/PJyj1WayGk  1404523914470957061
# 10  Use Remote Repositories in VS Code to browse a...  1404514979194228747
# 11  RT @K8sArchitect: Learn to debug Go microservi...  1404503914305802243
# 12  RT @Tyriar: .@MeganRogge_ and myself are about...  1404455568245469185
# 13  RT @github: You can now browse or even make ed...  1403743811453390848
# 14  RT @davidpine7: 💯 The @code extension API was ...  1403463051198803979
# 15  @olafurw Is your code in C:\FOO ? If so, press...  1403458434335350785
# 16  @olafurw We are working to make development en...  1403457108910116867
# 17  RT @miguelsolorio_: 🚀 Now that we shipped term...  1403456179527831556
# 18  Missed the live event? 🎉 You can now watch the...  1403402063170637825
# 19  @theGoldyMan @mattbierner We are on Electron 1...  1403057090214522883
#
#     favorite_count  in_reply_to_status_id_str  quoted_status_id lang  \
# 0                0                        NaN               NaN   en
# 1                0                        NaN               NaN   en
# 2                0                        NaN               NaN   en
# 3                0                        NaN               NaN   en
# 4                0                        NaN      1.404796e+18   en
# 5                2               1.404828e+18               NaN   cy
# 6                0                        NaN               NaN   en
# 7               63                        NaN               NaN   en
# 8                0                        NaN               NaN   en
# 9                9               1.404521e+18               NaN  und
# 10             369                        NaN               NaN   en
# 11               0                        NaN               NaN   en
# 12               0                        NaN               NaN   en
# 13               0                        NaN               NaN   en
# 14               0                        NaN               NaN   en
# 15               1               1.403458e+18               NaN   en
# 16              28               1.403450e+18               NaN   en
# 17               0                        NaN               NaN   en
# 18              58                        NaN      1.402350e+18   en
# 19               0               1.402883e+18               NaN   en
#
#     quoted_status_id_str                                    source_url  \
# 0                    NaN                            https://buffer.com
# 1                    NaN  https://about.twitter.com/products/tweetdeck
# 2                    NaN                            https://buffer.com
# 3                    NaN                            https://buffer.com
# 4           1.404796e+18                            https://buffer.com
# 5                    NaN  https://about.twitter.com/products/tweetdeck
# 6                    NaN                            https://buffer.com
# 7                    NaN                            https://buffer.com
# 8                    NaN                            https://buffer.com
# 9                    NaN  https://about.twitter.com/products/tweetdeck
# 10                   NaN  https://about.twitter.com/products/tweetdeck
# 11                   NaN                            https://buffer.com
# 12                   NaN                            https://buffer.com
# 13                   NaN  https://about.twitter.com/products/tweetdeck
# 14                   NaN                            https://buffer.com
# 15                   NaN  https://about.twitter.com/products/tweetdeck
# 16                   NaN  https://about.twitter.com/products/tweetdeck
# 17                   NaN  https://about.twitter.com/products/tweetdeck
# 18          1.402350e+18                    https://prod1.sprinklr.com
# 19                   NaN  https://about.twitter.com/products/tweetdeck
#
#     retweet_count  in_reply_to_user_id_str  in_reply_to_status_id  \
# 0              12                      NaN                    NaN
# 1              27                      NaN                    NaN
# 2              83                      NaN                    NaN
# 3              19                      NaN                    NaN
# 4              86                      NaN                    NaN
# 5               0               28189006.0           1.404828e+18
# 6              26                      NaN                    NaN
# 7              12                      NaN                    NaN
# 8              44                      NaN                    NaN
# 9               1                6619162.0           1.404521e+18
# 10             89                      NaN                    NaN
# 11             18                      NaN                    NaN
# 12             37                      NaN                    NaN
# 13            886                      NaN                    NaN
# 14              6                      NaN                    NaN
# 15              0               12514012.0           1.403458e+18
# 16              2               12514012.0           1.403450e+18
# 17             13                      NaN                    NaN
# 18             11                      NaN                    NaN
# 19              0               17621534.0           1.402883e+18
#
#                      id  user author
# 0   1405284556693856256  code   code
# 1   1405256932726697991  code   code
# 2   1405210223627935750  code   code
# 3   1405190182966640641  code   code
# 4   1404923676605157376  code   code
# 5   1404884676305588225  code   code
# 6   1404865795268780038  code   code
# 7   1404827556411588615  code   code
# 8   1404559526431543301  code   code
# 9   1404523914470957061  code   code
# 10  1404514979194228747  code   code
# 11  1404503914305802243  code   code
# 12  1404455568245469185  code   code
# 13  1403743811453390848  code   code
# 14  1403463051198803979  code   code
# 15  1403458434335350785  code   code
# 16  1403457108910116867  code   code
# 17  1403456179527831556  code   code
# 18  1403402063170637825  code   code
# 19  1403057090214522883  code   code
