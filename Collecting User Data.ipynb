# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (1.2.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.20.3)
# Requirement already satisfied: six>=1.5 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)

# %%
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (3.10.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from tweepy) (2.25.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from tweepy) (1.16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)

# %%
import tweepy #used to work with Twitter's API
import webbrowser
import time
import pandas as pd

# %%
consumer_key = "jzn0NU9EviCRRbONbUXX9a8VN" #pulled from developer account for Twitter
consumer_secret = "ULsKu9BjBPmZ3yY5NdS6EXUhGBNWKUWxtwKqFktBeqsOq1Y3ZQ" #pulled from developer account for Twitter
#key and secret is generated by Twitter developer account

# %%
callback_uri = 'oob'#url

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri) #authorization to pull data from Twitter's API
redirect_url = auth.get_authorization_url() 
print(redirect_url)
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=GaGM7QAAAAABQdBPAAABeioHKFQ

# %%
webbrowser.open(redirect_url)
# Out:
# True

# %%
user_pint_input = input("What's the pin value? ") #this is based upon Twitter Developer account
#Pin is generated new everytime this cell is run
# Out:
# What's the pin value? 9046399

# %%
auth.get_access_token(user_pint_input)
# Out:
# ('781482721-6928Gtnj95bK82PW3fYDxHFvU5T4l3SPI4VVF1X2',
#  'fTxclLJ4oxEmqshRhSbBibGoUiNq1l6941C0VyREdTf41')

# %%
print(auth.access_token, auth.access_token_secret)
# Out:
# 781482721-6928Gtnj95bK82PW3fYDxHFvU5T4l3SPI4VVF1X2 fTxclLJ4oxEmqshRhSbBibGoUiNq1l6941C0VyREdTf41

# %%
api = tweepy.API(auth)

# %%
def extract_timeline_as_df(timeline_list):
    columns = set()
    allowed_types = [str, int]
    tweets_data = []
    for status in timeline_list:
        status_dict = dict(vars(status))
        keys = status_dict.keys()
        single_tweet_data = {"user": status.user.screen_name, "author": status.author.screen_name}
        for k in keys:
            try:
                v_type = type(status_dict[k])
            except:
                v_type = None
            if v_type != None:
                if v_type in allowed_types:
                    single_tweet_data[k] = status_dict[k]
                    columns.add(k)
        tweets_data.append(single_tweet_data)


    header_cols = list(columns)
    header_cols.append("user")
    header_cols.append('author')
    df = pd.DataFrame(tweets_data, columns=header_cols)
    return df

# %%
# pulls data from Visual Studio Code's twitter page https://twitter.com/code
screen_name = "code"
#user = api.get_user(screen_name)
#user_timeline = user.timeline(screen_name)  # recent tweets are pulled in the spreadsheet
#print(user_timeline) 
# fetching the statuses
user_timeline = api.user_timeline(screen_name, count=200)
df1 = extract_timeline_as_df(user_timeline)
list(df1)
# Out:
# ['source_url',
#  'quoted_status_id',
#  'retweet_count',
#  'in_reply_to_user_id',
#  'lang',
#  'in_reply_to_user_id_str',
#  'in_reply_to_screen_name',
#  'quoted_status_id_str',
#  'in_reply_to_status_id_str',
#  'favorite_count',
#  'text',
#  'id',
#  'id_str',
#  'in_reply_to_status_id',
#  'source',
#  'user',
#  'author']

# %%
screen_name = "code" #pulls data from Visual Studio Code's twitter page https://twitter.com/code
user = api.get_user(screen_name)
user_timeline = user.timeline() #recent tweets are pulled in the spreadsheet
df1 = extract_timeline_as_df(user_timeline)
df1.head()
# Out:
#                                      source_url  quoted_status_id  \
# 0                            https://buffer.com      1.405539e+18
# 1                    https://prod1.sprinklr.com      1.405553e+18
# 2                            https://buffer.com               NaN
# 3  https://about.twitter.com/products/tweetdeck               NaN
# 4  https://about.twitter.com/products/tweetdeck               NaN
#
#    retweet_count  in_reply_to_user_id lang in_reply_to_user_id_str  \
# 0              6                  NaN   en                     NaN
# 1              6                  NaN   en                     NaN
# 2            235                  NaN   en                     NaN
# 3             72                  NaN   en                     NaN
# 4              2          243794902.0   en               243794902
#
#   in_reply_to_screen_name quoted_status_id_str in_reply_to_status_id_str  \
# 0                     NaN  1405538503048327169                       NaN
# 1                     NaN  1405552832208683011                       NaN
# 2                     NaN                  NaN                       NaN
# 3                     NaN                  NaN                       NaN
# 4                 TpoM6oH                  NaN       1405562974148861952
#
#    favorite_count                                               text  \
# 0               0  RT @ClaudiaRegio: Want to learn about #jupyter...
# 1              46  Missed the livestream? You can now catch it on...
# 2               0  RT @LeoKac333: Check out my VSCode extension -...
# 3               0  RT @pythonvscode: And the June release of the ...
# 4              27  @TpoM6oH Yup, it's a new feature! Read more in...
#
#                     id               id_str  in_reply_to_status_id  \
# 0  1405999767604416512  1405999767604416512                    NaN
# 1  1405918729045692419  1405918729045692419                    NaN
# 2  1405647699483967493  1405647699483967493                    NaN
# 3  1405586524066881541  1405586524066881541                    NaN
# 4  1405564371913392133  1405564371913392133           1.405563e+18
#
#                 source  user author
# 0               Buffer  code   code
# 1  Sprinklr Publishing  code   code
# 2               Buffer  code   code
# 3            TweetDeck  code   code
# 4            TweetDeck  code   code

# %%
df1.to_csv('tweetspreadsheet.csv', index=False)

# %%
df1_saved_file = pd.read_csv('tweetspreadsheet.csv')
df1_saved_file
# Out:
#                                       source_url  quoted_status_id  \
# 0                             https://buffer.com      1.405539e+18
# 1                     https://prod1.sprinklr.com      1.405553e+18
# 2                             https://buffer.com               NaN
# 3   https://about.twitter.com/products/tweetdeck               NaN
# 4   https://about.twitter.com/products/tweetdeck               NaN
# 5                             https://buffer.com               NaN
# 6                             https://buffer.com               NaN
# 7   https://about.twitter.com/products/tweetdeck               NaN
# 8                             https://buffer.com               NaN
# 9                             https://buffer.com               NaN
# 10                            https://buffer.com      1.404796e+18
# 11  https://about.twitter.com/products/tweetdeck               NaN
# 12                            https://buffer.com               NaN
# 13                            https://buffer.com               NaN
# 14                            https://buffer.com               NaN
# 15  https://about.twitter.com/products/tweetdeck               NaN
# 16  https://about.twitter.com/products/tweetdeck               NaN
# 17                            https://buffer.com               NaN
# 18                            https://buffer.com               NaN
# 19  https://about.twitter.com/products/tweetdeck               NaN
#
#     retweet_count  in_reply_to_user_id lang  in_reply_to_user_id_str  \
# 0               6                  NaN   en                      NaN
# 1               6                  NaN   en                      NaN
# 2             235                  NaN   en                      NaN
# 3              72                  NaN   en                      NaN
# 4               2          243794902.0   en              243794902.0
# 5               9                  NaN   en                      NaN
# 6              24                  NaN   en                      NaN
# 7              37                  NaN   en                      NaN
# 8              96                  NaN   en                      NaN
# 9              22                  NaN   en                      NaN
# 10             95                  NaN   en                      NaN
# 11              0           28189006.0   cy               28189006.0
# 12             26                  NaN   en                      NaN
# 13             12                  NaN   en                      NaN
# 14             47                  NaN   en                      NaN
# 15              1            6619162.0  und                6619162.0
# 16             94                  NaN   en                      NaN
# 17             19                  NaN   en                      NaN
# 18             38                  NaN   en                      NaN
# 19            935                  NaN   en                      NaN
#
#    in_reply_to_screen_name  quoted_status_id_str  in_reply_to_status_id_str  \
# 0                      NaN          1.405539e+18                        NaN
# 1                      NaN          1.405553e+18                        NaN
# 2                      NaN                   NaN                        NaN
# 3                      NaN                   NaN                        NaN
# 4                  TpoM6oH                   NaN               1.405563e+18
# 5                      NaN                   NaN                        NaN
# 6                      NaN                   NaN                        NaN
# 7                      NaN                   NaN                        NaN
# 8                      NaN                   NaN                        NaN
# 9                      NaN                   NaN                        NaN
# 10                     NaN          1.404796e+18                        NaN
# 11              marcduiker                   NaN               1.404828e+18
# 12                     NaN                   NaN                        NaN
# 13                     NaN                   NaN                        NaN
# 14                     NaN                   NaN                        NaN
# 15                    n1k0                   NaN               1.404521e+18
# 16                     NaN                   NaN                        NaN
# 17                     NaN                   NaN                        NaN
# 18                     NaN                   NaN                        NaN
# 19                     NaN                   NaN                        NaN
#
#     favorite_count                                               text  \
# 0                0  RT @ClaudiaRegio: Want to learn about #jupyter...
# 1               46  Missed the livestream? You can now catch it on...
# 2                0  RT @LeoKac333: Check out my VSCode extension -...
# 3                0  RT @pythonvscode: And the June release of the ...
# 4               27  @TpoM6oH Yup, it's a new feature! Read more in...
# 5               37  🍿 We're going live in just a few mins with @su...
# 6                0  RT @mattbierner: Today's @code setting: sugges...
# 7                0  RT @yaojinyang: Welcome to May’s updates on VS...
# 8                0  RT @freeCodeCamp: Have you heard? You can now ...
# 9                0  RT @mattbierner: Today's @code tip: terminal t...
# 10               0  RT @DynamicWebPaige: Have you ever tried @code...
# 11               2  @marcduiker @suzmue CC: @anthonypjshaw Gopher ...
# 12               0  RT @pythonvscode: The June release for the #ju...
# 13              63  💬 What's so special about #Golang? And how can...
# 14               0  RT @GarvNanwani: @code tip -\n\nNormally when ...
# 15              11                    @n1k0 👀 https://t.co/PJyj1WayGk
# 16             374  Use Remote Repositories in VS Code to browse a...
# 17               0  RT @K8sArchitect: Learn to debug Go microservi...
# 18               0  RT @Tyriar: .@MeganRogge_ and myself are about...
# 19               0  RT @github: You can now browse or even make ed...
#
#                      id               id_str  in_reply_to_status_id  \
# 0   1405999767604416512  1405999767604416512                    NaN
# 1   1405918729045692419  1405918729045692419                    NaN
# 2   1405647699483967493  1405647699483967493                    NaN
# 3   1405586524066881541  1405586524066881541                    NaN
# 4   1405564371913392133  1405564371913392133           1.405563e+18
# 5   1405552832208683011  1405552832208683011                    NaN
# 6   1405284556693856256  1405284556693856256                    NaN
# 7   1405256932726697991  1405256932726697991                    NaN
# 8   1405210223627935750  1405210223627935750                    NaN
# 9   1405190182966640641  1405190182966640641                    NaN
# 10  1404923676605157376  1404923676605157376                    NaN
# 11  1404884676305588225  1404884676305588225           1.404828e+18
# 12  1404865795268780038  1404865795268780038                    NaN
# 13  1404827556411588615  1404827556411588615                    NaN
# 14  1404559526431543301  1404559526431543301                    NaN
# 15  1404523914470957061  1404523914470957061           1.404521e+18
# 16  1404514979194228747  1404514979194228747                    NaN
# 17  1404503914305802243  1404503914305802243                    NaN
# 18  1404455568245469185  1404455568245469185                    NaN
# 19  1403743811453390848  1403743811453390848                    NaN
#
#                  source  user author
# 0                Buffer  code   code
# 1   Sprinklr Publishing  code   code
# 2                Buffer  code   code
# 3             TweetDeck  code   code
# 4             TweetDeck  code   code
# 5                Buffer  code   code
# 6                Buffer  code   code
# 7             TweetDeck  code   code
# 8                Buffer  code   code
# 9                Buffer  code   code
# 10               Buffer  code   code
# 11            TweetDeck  code   code
# 12               Buffer  code   code
# 13               Buffer  code   code
# 14               Buffer  code   code
# 15            TweetDeck  code   code
# 16            TweetDeck  code   code
# 17               Buffer  code   code
# 18               Buffer  code   code
# 19            TweetDeck  code   code
