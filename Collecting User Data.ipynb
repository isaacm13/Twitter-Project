# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.20.3)
# Requirement already satisfied: six>=1.5 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)

# %%
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (3.10.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from tweepy) (2.25.1)
# Requirement already satisfied: six>=1.10.0 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from tweepy) (1.16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.26.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)

# %%
import tweepy #used to work with Twitter's API
import webbrowser
import time
import pandas as pd

# %%
consumer_key = "jzn0NU9EviCRRbONbUXX9a8VN" #pulled from developer account for Twitter
consumer_secret = "ULsKu9BjBPmZ3yY5NdS6EXUhGBNWKUWxtwKqFktBeqsOq1Y3ZQ" #pulled from developer account for Twitter
#key and secret is generated by Twitter developer account

# %%
callback_uri = 'oob'#url

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri) #authorization to pull data from Twitter's API
redirect_url = auth.get_authorization_url() 
print(redirect_url)
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=P8CvgAAAAAABQdBPAAABeioDfdI

# %%
webbrowser.open(redirect_url)
# Out:
# True

# %%
user_pint_input = input("What's the pin value? ") #this is based upon Twitter Developer account
#Pin is generated new everytime this cell is run
# Out:
# What's the pin value? 6147657

# %%
auth.get_access_token(user_pint_input)
# Out:
# ('781482721-6928Gtnj95bK82PW3fYDxHFvU5T4l3SPI4VVF1X2',
#  'fTxclLJ4oxEmqshRhSbBibGoUiNq1l6941C0VyREdTf41')

# %%
print(auth.access_token, auth.access_token_secret)
# Out:
# 781482721-6928Gtnj95bK82PW3fYDxHFvU5T4l3SPI4VVF1X2 fTxclLJ4oxEmqshRhSbBibGoUiNq1l6941C0VyREdTf41

# %%
api = tweepy.API(auth)

# %%
def extract_timeline_as_df(timeline_list):
    columns = set()
    allowed_types = [str, int]
    tweets_data = []
    for status in timeline_list:
        status_dict = dict(vars(status))
        keys = status_dict.keys()
        single_tweet_data = {"user": status.user.screen_name, "author": status.author.screen_name}
        for k in keys:
            try:
                v_type = type(status_dict[k])
            except:
                v_type = None
            if v_type != None:
                if v_type in allowed_types:
                    single_tweet_data[k] = status_dict[k]
                    columns.add(k)
        tweets_data.append(single_tweet_data)


    header_cols = list(columns)
    header_cols.append("user")
    header_cols.append('author')
    df = pd.DataFrame(tweets_data, columns=header_cols)
    return df

# %%
# pulls data from Visual Studio Code's twitter page https://twitter.com/code
screen_name = "code"
#user = api.get_user(screen_name)
#user_timeline = user.timeline(screen_name)  # recent tweets are pulled in the spreadsheet
#print(user_timeline) 
# fetching the statuses
user_timeline = api.user_timeline(screen_name, count=200)
df1 = extract_timeline_as_df(user_timeline)
len(df1)
# Out:
# 200

# %%
screen_name = "code" #pulls data from Visual Studio Code's twitter page https://twitter.com/code
user = api.get_user(screen_name)
user_timeline = user.timeline() #recent tweets are pulled in the spreadsheet
df1 = extract_timeline_as_df(user_timeline)
df1.head()
# Out:
#                     id  favorite_count               id_str  \
# 0  1405999767604416512               0  1405999767604416512
# 1  1405918729045692419              46  1405918729045692419
# 2  1405647699483967493               0  1405647699483967493
# 3  1405586524066881541               0  1405586524066881541
# 4  1405564371913392133              27  1405564371913392133
#
#                 source  quoted_status_id  retweet_count lang  \
# 0               Buffer      1.405539e+18              6   en
# 1  Sprinklr Publishing      1.405553e+18              6   en
# 2               Buffer               NaN            235   en
# 3            TweetDeck               NaN             72   en
# 4            TweetDeck               NaN              2   en
#
#    in_reply_to_status_id in_reply_to_user_id_str in_reply_to_screen_name  \
# 0                    NaN                     NaN                     NaN
# 1                    NaN                     NaN                     NaN
# 2                    NaN                     NaN                     NaN
# 3                    NaN                     NaN                     NaN
# 4           1.405563e+18               243794902                 TpoM6oH
#
#   quoted_status_id_str                                               text  \
# 0  1405538503048327169  RT @ClaudiaRegio: Want to learn about #jupyter...
# 1  1405552832208683011  Missed the livestream? You can now catch it on...
# 2                  NaN  RT @LeoKac333: Check out my VSCode extension -...
# 3                  NaN  RT @pythonvscode: And the June release of the ...
# 4                  NaN  @TpoM6oH Yup, it's a new feature! Read more in...
#
#   in_reply_to_status_id_str                                    source_url  \
# 0                       NaN                            https://buffer.com
# 1                       NaN                    https://prod1.sprinklr.com
# 2                       NaN                            https://buffer.com
# 3                       NaN  https://about.twitter.com/products/tweetdeck
# 4       1405562974148861952  https://about.twitter.com/products/tweetdeck
#
#    in_reply_to_user_id  user author
# 0                  NaN  code   code
# 1                  NaN  code   code
# 2                  NaN  code   code
# 3                  NaN  code   code
# 4          243794902.0  code   code

# %%
df1.to_csv('tweetspreadsheet.csv', index=False)

# %%
df1_saved_file = pd.read_csv('tweetspreadsheet.csv')
df1_saved_file
# Out:
#                      id  favorite_count               id_str  \
# 0   1405999767604416512               0  1405999767604416512
# 1   1405918729045692419              46  1405918729045692419
# 2   1405647699483967493               0  1405647699483967493
# 3   1405586524066881541               0  1405586524066881541
# 4   1405564371913392133              27  1405564371913392133
# 5   1405552832208683011              37  1405552832208683011
# 6   1405284556693856256               0  1405284556693856256
# 7   1405256932726697991               0  1405256932726697991
# 8   1405210223627935750               0  1405210223627935750
# 9   1405190182966640641               0  1405190182966640641
# 10  1404923676605157376               0  1404923676605157376
# 11  1404884676305588225               2  1404884676305588225
# 12  1404865795268780038               0  1404865795268780038
# 13  1404827556411588615              63  1404827556411588615
# 14  1404559526431543301               0  1404559526431543301
# 15  1404523914470957061              11  1404523914470957061
# 16  1404514979194228747             374  1404514979194228747
# 17  1404503914305802243               0  1404503914305802243
# 18  1404455568245469185               0  1404455568245469185
# 19  1403743811453390848               0  1403743811453390848
#
#                  source  quoted_status_id  retweet_count lang  \
# 0                Buffer      1.405539e+18              6   en
# 1   Sprinklr Publishing      1.405553e+18              6   en
# 2                Buffer               NaN            235   en
# 3             TweetDeck               NaN             72   en
# 4             TweetDeck               NaN              2   en
# 5                Buffer               NaN              9   en
# 6                Buffer               NaN             24   en
# 7             TweetDeck               NaN             37   en
# 8                Buffer               NaN             96   en
# 9                Buffer               NaN             22   en
# 10               Buffer      1.404796e+18             95   en
# 11            TweetDeck               NaN              0   cy
# 12               Buffer               NaN             26   en
# 13               Buffer               NaN             12   en
# 14               Buffer               NaN             47   en
# 15            TweetDeck               NaN              1  und
# 16            TweetDeck               NaN             94   en
# 17               Buffer               NaN             19   en
# 18               Buffer               NaN             38   en
# 19            TweetDeck               NaN            935   en
#
#     in_reply_to_status_id  in_reply_to_user_id_str in_reply_to_screen_name  \
# 0                     NaN                      NaN                     NaN
# 1                     NaN                      NaN                     NaN
# 2                     NaN                      NaN                     NaN
# 3                     NaN                      NaN                     NaN
# 4            1.405563e+18              243794902.0                 TpoM6oH
# 5                     NaN                      NaN                     NaN
# 6                     NaN                      NaN                     NaN
# 7                     NaN                      NaN                     NaN
# 8                     NaN                      NaN                     NaN
# 9                     NaN                      NaN                     NaN
# 10                    NaN                      NaN                     NaN
# 11           1.404828e+18               28189006.0              marcduiker
# 12                    NaN                      NaN                     NaN
# 13                    NaN                      NaN                     NaN
# 14                    NaN                      NaN                     NaN
# 15           1.404521e+18                6619162.0                    n1k0
# 16                    NaN                      NaN                     NaN
# 17                    NaN                      NaN                     NaN
# 18                    NaN                      NaN                     NaN
# 19                    NaN                      NaN                     NaN
#
#     quoted_status_id_str                                               text  \
# 0           1.405539e+18  RT @ClaudiaRegio: Want to learn about #jupyter...
# 1           1.405553e+18  Missed the livestream? You can now catch it on...
# 2                    NaN  RT @LeoKac333: Check out my VSCode extension -...
# 3                    NaN  RT @pythonvscode: And the June release of the ...
# 4                    NaN  @TpoM6oH Yup, it's a new feature! Read more in...
# 5                    NaN  🍿 We're going live in just a few mins with @su...
# 6                    NaN  RT @mattbierner: Today's @code setting: sugges...
# 7                    NaN  RT @yaojinyang: Welcome to May’s updates on VS...
# 8                    NaN  RT @freeCodeCamp: Have you heard? You can now ...
# 9                    NaN  RT @mattbierner: Today's @code tip: terminal t...
# 10          1.404796e+18  RT @DynamicWebPaige: Have you ever tried @code...
# 11                   NaN  @marcduiker @suzmue CC: @anthonypjshaw Gopher ...
# 12                   NaN  RT @pythonvscode: The June release for the #ju...
# 13                   NaN  💬 What's so special about #Golang? And how can...
# 14                   NaN  RT @GarvNanwani: @code tip -\n\nNormally when ...
# 15                   NaN                    @n1k0 👀 https://t.co/PJyj1WayGk
# 16                   NaN  Use Remote Repositories in VS Code to browse a...
# 17                   NaN  RT @K8sArchitect: Learn to debug Go microservi...
# 18                   NaN  RT @Tyriar: .@MeganRogge_ and myself are about...
# 19                   NaN  RT @github: You can now browse or even make ed...
#
#     in_reply_to_status_id_str                                    source_url  \
# 0                         NaN                            https://buffer.com
# 1                         NaN                    https://prod1.sprinklr.com
# 2                         NaN                            https://buffer.com
# 3                         NaN  https://about.twitter.com/products/tweetdeck
# 4                1.405563e+18  https://about.twitter.com/products/tweetdeck
# 5                         NaN                            https://buffer.com
# 6                         NaN                            https://buffer.com
# 7                         NaN  https://about.twitter.com/products/tweetdeck
# 8                         NaN                            https://buffer.com
# 9                         NaN                            https://buffer.com
# 10                        NaN                            https://buffer.com
# 11               1.404828e+18  https://about.twitter.com/products/tweetdeck
# 12                        NaN                            https://buffer.com
# 13                        NaN                            https://buffer.com
# 14                        NaN                            https://buffer.com
# 15               1.404521e+18  https://about.twitter.com/products/tweetdeck
# 16                        NaN  https://about.twitter.com/products/tweetdeck
# 17                        NaN                            https://buffer.com
# 18                        NaN                            https://buffer.com
# 19                        NaN  https://about.twitter.com/products/tweetdeck
#
#     in_reply_to_user_id  user author
# 0                   NaN  code   code
# 1                   NaN  code   code
# 2                   NaN  code   code
# 3                   NaN  code   code
# 4           243794902.0  code   code
# 5                   NaN  code   code
# 6                   NaN  code   code
# 7                   NaN  code   code
# 8                   NaN  code   code
# 9                   NaN  code   code
# 10                  NaN  code   code
# 11           28189006.0  code   code
# 12                  NaN  code   code
# 13                  NaN  code   code
# 14                  NaN  code   code
# 15            6619162.0  code   code
# 16                  NaN  code   code
# 17                  NaN  code   code
# 18                  NaN  code   code
# 19                  NaN  code   code
