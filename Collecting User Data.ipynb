# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (1.2.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)

# %%
import tweepy #used to work with Twitter's API
import webbrowser
import time
import pandas as pd

# %%
consumer_key = "jzn0NU9EviCRRbONbUXX9a8VN" #pulled from developer account for Twitter
consumer_secret = "ULsKu9BjBPmZ3yY5NdS6EXUhGBNWKUWxtwKqFktBeqsOq1Y3ZQ" #pulled from developer account for Twitter
#key and secret is generated by Twitter developer account

# %%
callback_uri = 'oob'#url

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri) #authorization to pull data from Twitter's API
redirect_url = auth.get_authorization_url() 
print(redirect_url)
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=KsJi2QAAAAABQdBPAAABegzTufo

# %%
webbrowser.open(redirect_url)
# Out:
# True

# %%
user_pint_input = input("What's the pin value? ") #this is based upon Twitter Developer account
#Pin is generated new everytime this cell is run
# Out:
# What's the pin value? 9200004

# %%
auth.get_access_token(user_pint_input)
# Out:
# ('781482721-6928Gtnj95bK82PW3fYDxHFvU5T4l3SPI4VVF1X2',
#  'fTxclLJ4oxEmqshRhSbBibGoUiNq1l6941C0VyREdTf41')

# %%
print(auth.access_token, auth.access_token_secret)
# Out:
# 781482721-6928Gtnj95bK82PW3fYDxHFvU5T4l3SPI4VVF1X2 fTxclLJ4oxEmqshRhSbBibGoUiNq1l6941C0VyREdTf41

# %%
api = tweepy.API(auth)

# %%
def extract_timeline_as_df(timeline_list):
    columns = set()
    allowed_types = [str, int]
    tweets_data = []
    for status in timeline_list:
        status_dict = dict(vars(status))
        keys = status_dict.keys()
        single_tweet_data = {"user": status.user.screen_name, "author": status.author.screen_name}
        for k in keys:
            try:
                v_type = type(status_dict[k])
            except:
                v_type = None
            if v_type != None:
                if v_type in allowed_types:
                    single_tweet_data[k] = status_dict[k]
                    columns.add(k)
        tweets_data.append(single_tweet_data)


    header_cols = list(columns)
    header_cols.append("user")
    header_cols.append('author')
    df = pd.DataFrame(tweets_data, columns=header_cols)
    return df

# %%
screen_name = "code" #pulls data from Visual Studio Code's twitter page https://twitter.com/code
user = api.get_user(screen_name)
user_timeline = user.timeline() #recent tweets are pulled in the spreadsheet
df1 = extract_timeline_as_df(user_timeline)
df1.head()
# Out:
#    favorite_count  retweet_count  quoted_status_id     source  \
# 0               0             16               NaN     Buffer
# 1               7              1               NaN  TweetDeck
# 2             173             38               NaN  TweetDeck
# 3               0             13               NaN     Buffer
# 4               0             27               NaN     Buffer
#
#   in_reply_to_status_id_str lang  \
# 0                       NaN   en
# 1       1404521280863416322  und
# 2                       NaN   en
# 3                       NaN   en
# 4                       NaN   en
#
#                                                 text               id_str  \
# 0  RT @GarvNanwani: @code tip -\n\nNormally when ...  1404559526431543301
# 1                    @n1k0 👀 https://t.co/PJyj1WayGk  1404523914470957061
# 2  Use Remote Repositories in VS Code to browse a...  1404514979194228747
# 3  RT @K8sArchitect: Learn to debug Go microservi...  1404503914305802243
# 4  RT @Tyriar: .@MeganRogge_ and myself are about...  1404455568245469185
#
#   quoted_status_id_str in_reply_to_user_id_str  \
# 0                  NaN                     NaN
# 1                  NaN                 6619162
# 2                  NaN                     NaN
# 3                  NaN                     NaN
# 4                  NaN                     NaN
#
#                                      source_url  in_reply_to_user_id  \
# 0                            https://buffer.com                  NaN
# 1  https://about.twitter.com/products/tweetdeck            6619162.0
# 2  https://about.twitter.com/products/tweetdeck                  NaN
# 3                            https://buffer.com                  NaN
# 4                            https://buffer.com                  NaN
#
#   in_reply_to_screen_name                   id  in_reply_to_status_id  user  \
# 0                     NaN  1404559526431543301                    NaN  code
# 1                    n1k0  1404523914470957061           1.404521e+18  code
# 2                     NaN  1404514979194228747                    NaN  code
# 3                     NaN  1404503914305802243                    NaN  code
# 4                     NaN  1404455568245469185                    NaN  code
#
#   author
# 0   code
# 1   code
# 2   code
# 3   code
# 4   code

# %%
df1.to_csv('tweetspreadsheet.csv', index=False)

# %%
df1_saved_file = pd.read_csv('tweetspreadsheet.csv')
df1_saved_file
# Out:
#     favorite_count  retweet_count  quoted_status_id               source  \
# 0                0             16               NaN               Buffer
# 1                7              1               NaN            TweetDeck
# 2              173             38               NaN            TweetDeck
# 3                0             13               NaN               Buffer
# 4                0             27               NaN               Buffer
# 5                0            853               NaN            TweetDeck
# 6                0              6               NaN               Buffer
# 7                1              0               NaN            TweetDeck
# 8               28              2               NaN            TweetDeck
# 9                0             11               NaN            TweetDeck
# 10              58             11      1.402350e+18  Sprinklr Publishing
# 11               0              0               NaN            TweetDeck
# 12             450            110               NaN      Twitter Web App
# 13             158             25               NaN            TweetDeck
# 14               0             25               NaN            TweetDeck
# 15               0             16               NaN      Twitter Web App
# 16             211             49               NaN            TweetDeck
# 17              67             13      1.401947e+18               Buffer
# 18              15              0               NaN            TweetDeck
# 19               0             80               NaN               Buffer
#
#     in_reply_to_status_id_str lang  \
# 0                         NaN   en
# 1                1.404521e+18  und
# 2                         NaN   en
# 3                         NaN   en
# 4                         NaN   en
# 5                         NaN   en
# 6                         NaN   en
# 7                1.403458e+18   en
# 8                1.403450e+18   en
# 9                         NaN   en
# 10                        NaN   en
# 11               1.402883e+18   en
# 12                        NaN   en
# 13                        NaN   en
# 14                        NaN   en
# 15                        NaN   en
# 16                        NaN   en
# 17                        NaN   en
# 18               1.401936e+18   en
# 19                        NaN   en
#
#                                                  text               id_str  \
# 0   RT @GarvNanwani: @code tip -\n\nNormally when ...  1404559526431543301
# 1                     @n1k0 👀 https://t.co/PJyj1WayGk  1404523914470957061
# 2   Use Remote Repositories in VS Code to browse a...  1404514979194228747
# 3   RT @K8sArchitect: Learn to debug Go microservi...  1404503914305802243
# 4   RT @Tyriar: .@MeganRogge_ and myself are about...  1404455568245469185
# 5   RT @github: You can now browse or even make ed...  1403743811453390848
# 6   RT @davidpine7: 💯 The @code extension API was ...  1403463051198803979
# 7   @olafurw Is your code in C:\FOO ? If so, press...  1403458434335350785
# 8   @olafurw We are working to make development en...  1403457108910116867
# 9   RT @miguelsolorio_: 🚀 Now that we shipped term...  1403456179527831556
# 10  Missed the live event? 🎉 You can now watch the...  1403402063170637825
# 11  @theGoldyMan @mattbierner We are on Electron 1...  1403057090214522883
# 12  🎉 The May @code release is here! Check out wha...  1403049441381302277
# 13  📣 We're going live shortly with the latest rel...  1403001506329022479
# 14  RT @mattbierner: Today's @code setting: Menu b...  1402742275554254848
# 15  RT @chrisraygill: Hi friends! 👋\n\nI'm working...  1402372297944616965
# 16  We're getting ready for a new VS Code release ...  1402350147040792579
# 17  If you use C/C++ in VS Code, our team wants to...  1401967203566690307
# 18  @patrickdebois The idea is that git will smart...  1401956971306131456
# 19  RT @Tyriar: Luna Paint v0.6 for @code is out! ...  1401934034557497347
#
#     quoted_status_id_str  in_reply_to_user_id_str  \
# 0                    NaN                      NaN
# 1                    NaN                6619162.0
# 2                    NaN                      NaN
# 3                    NaN                      NaN
# 4                    NaN                      NaN
# 5                    NaN                      NaN
# 6                    NaN                      NaN
# 7                    NaN               12514012.0
# 8                    NaN               12514012.0
# 9                    NaN                      NaN
# 10          1.402350e+18                      NaN
# 11                   NaN               17621534.0
# 12                   NaN                      NaN
# 13                   NaN                      NaN
# 14                   NaN                      NaN
# 15                   NaN                      NaN
# 16                   NaN                      NaN
# 17          1.401947e+18                      NaN
# 18                   NaN               15649735.0
# 19                   NaN                      NaN
#
#                                       source_url  in_reply_to_user_id  \
# 0                             https://buffer.com                  NaN
# 1   https://about.twitter.com/products/tweetdeck            6619162.0
# 2   https://about.twitter.com/products/tweetdeck                  NaN
# 3                             https://buffer.com                  NaN
# 4                             https://buffer.com                  NaN
# 5   https://about.twitter.com/products/tweetdeck                  NaN
# 6                             https://buffer.com                  NaN
# 7   https://about.twitter.com/products/tweetdeck           12514012.0
# 8   https://about.twitter.com/products/tweetdeck           12514012.0
# 9   https://about.twitter.com/products/tweetdeck                  NaN
# 10                    https://prod1.sprinklr.com                  NaN
# 11  https://about.twitter.com/products/tweetdeck           17621534.0
# 12                    https://mobile.twitter.com                  NaN
# 13  https://about.twitter.com/products/tweetdeck                  NaN
# 14  https://about.twitter.com/products/tweetdeck                  NaN
# 15                    https://mobile.twitter.com                  NaN
# 16  https://about.twitter.com/products/tweetdeck                  NaN
# 17                            https://buffer.com                  NaN
# 18  https://about.twitter.com/products/tweetdeck           15649735.0
# 19                            https://buffer.com                  NaN
#
#    in_reply_to_screen_name                   id  in_reply_to_status_id  user  \
# 0                      NaN  1404559526431543301                    NaN  code
# 1                     n1k0  1404523914470957061           1.404521e+18  code
# 2                      NaN  1404514979194228747                    NaN  code
# 3                      NaN  1404503914305802243                    NaN  code
# 4                      NaN  1404455568245469185                    NaN  code
# 5                      NaN  1403743811453390848                    NaN  code
# 6                      NaN  1403463051198803979                    NaN  code
# 7                  olafurw  1403458434335350785           1.403458e+18  code
# 8                  olafurw  1403457108910116867           1.403450e+18  code
# 9                      NaN  1403456179527831556                    NaN  code
# 10                     NaN  1403402063170637825                    NaN  code
# 11             theGoldyMan  1403057090214522883           1.402883e+18  code
# 12                     NaN  1403049441381302277                    NaN  code
# 13                     NaN  1403001506329022479                    NaN  code
# 14                     NaN  1402742275554254848                    NaN  code
# 15                     NaN  1402372297944616965                    NaN  code
# 16                     NaN  1402350147040792579                    NaN  code
# 17                     NaN  1401967203566690307                    NaN  code
# 18           patrickdebois  1401956971306131456           1.401936e+18  code
# 19                     NaN  1401934034557497347                    NaN  code
#
#    author
# 0    code
# 1    code
# 2    code
# 3    code
# 4    code
# 5    code
# 6    code
# 7    code
# 8    code
# 9    code
# 10   code
# 11   code
# 12   code
# 13   code
# 14   code
# 15   code
# 16   code
# 17   code
# 18   code
# 19   code
