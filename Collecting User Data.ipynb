# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\black\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)

# %%
# !pip install tweepy
# Out:
# Collecting tweepy
#   Using cached tweepy-3.10.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: six>=1.10.0 in c:\users\black\anaconda3\lib\site-packages (from tweepy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\black\anaconda3\lib\site-packages (from tweepy) (2.25.1)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\black\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\black\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\black\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\black\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (4.0.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\black\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.1.1 requests-oauthlib-1.3.0 tweepy-3.10.0

# %%
import tweepy #used to work with Twitter's API
import webbrowser
import time
import pandas as pd

# %%
consumer_key = "jzn0NU9EviCRRbONbUXX9a8VN" #pulled from developer account for Twitter
consumer_secret = "ULsKu9BjBPmZ3yY5NdS6EXUhGBNWKUWxtwKqFktBeqsOq1Y3ZQ" #pulled from developer account for Twitter
#key and secret is generated by Twitter developer account

# %%
callback_uri = 'oob'#url

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri) #authorization to pull data from Twitter's API
redirect_url = auth.get_authorization_url() 
print(redirect_url)
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=6jL4bQAAAAABQdBPAAABeiEaBIo

# %%
webbrowser.open(redirect_url)
# Out:
# True

# %%
user_pint_input = input("What's the pin value? ") #this is based upon Twitter Developer account
#Pin is generated new everytime this cell is run

# %%
auth.get_access_token(user_pint_input)
# Out:
# ('781482721-6928Gtnj95bK82PW3fYDxHFvU5T4l3SPI4VVF1X2',
#  'fTxclLJ4oxEmqshRhSbBibGoUiNq1l6941C0VyREdTf41')

# %%
print(auth.access_token, auth.access_token_secret)
# Out:
# 781482721-6928Gtnj95bK82PW3fYDxHFvU5T4l3SPI4VVF1X2 fTxclLJ4oxEmqshRhSbBibGoUiNq1l6941C0VyREdTf41

# %%
api = tweepy.API(auth)

# %%
def extract_timeline_as_df(timeline_list):
    columns = set()
    allowed_types = [str, int]
    tweets_data = []
    for status in timeline_list:
        status_dict = dict(vars(status))
        keys = status_dict.keys()
        single_tweet_data = {"user": status.user.screen_name, "author": status.author.screen_name}
        for k in keys:
            try:
                v_type = type(status_dict[k])
            except:
                v_type = None
            if v_type != None:
                if v_type in allowed_types:
                    single_tweet_data[k] = status_dict[k]
                    columns.add(k)
        tweets_data.append(single_tweet_data)


    header_cols = list(columns)
    header_cols.append("user")
    header_cols.append('author')
    df = pd.DataFrame(tweets_data, columns=header_cols)
    return df

# %%
# pulls data from Visual Studio Code's twitter page https://twitter.com/code
screen_name = "code"
#user = api.get_user(screen_name)
#user_timeline = user.timeline(screen_name)  # recent tweets are pulled in the spreadsheet
#print(user_timeline) 
# fetching the statuses
user_timeline = api.user_timeline(screen_name, count=200)
df1 = extract_timeline_as_df(user_timeline)
list(df1)
# Out:
# ['in_reply_to_user_id_str',
#  'in_reply_to_user_id',
#  'source',
#  'id_str',
#  'lang',
#  'source_url',
#  'favorite_count',
#  'retweet_count',
#  'in_reply_to_screen_name',
#  'text',
#  'quoted_status_id_str',
#  'quoted_status_id',
#  'in_reply_to_status_id',
#  'id',
#  'in_reply_to_status_id_str',
#  'user',
#  'author']

# %%
screen_name = "code" #pulls data from Visual Studio Code's twitter page https://twitter.com/code
user = api.get_user(screen_name)
user_timeline = user.timeline() #recent tweets are pulled in the spreadsheet
df1 = extract_timeline_as_df(user_timeline)
df1.head()
# Out:
#                                      source_url               id_str  \
# 0                    https://prod1.sprinklr.com  1405918729045692419
# 1                            https://buffer.com  1405647699483967493
# 2  https://about.twitter.com/products/tweetdeck  1405586524066881541
# 3  https://about.twitter.com/products/tweetdeck  1405564371913392133
# 4                            https://buffer.com  1405552832208683011
#
#                 source                                               text  \
# 0  Sprinklr Publishing  Missed the livestream? You can now catch it on...
# 1               Buffer  RT @LeoKac333: Check out my VSCode extension -...
# 2            TweetDeck  RT @pythonvscode: And the June release of the ...
# 3            TweetDeck  @TpoM6oH Yup, it's a new feature! Read more in...
# 4               Buffer  🍿 We're going live in just a few mins with @su...
#
#    favorite_count lang in_reply_to_status_id_str in_reply_to_user_id_str  \
# 0              35   en                       NaN                     NaN
# 1               0   en                       NaN                     NaN
# 2               0   en                       NaN                     NaN
# 3              25   en       1405562974148861952               243794902
# 4              36   en                       NaN                     NaN
#
#    in_reply_to_status_id  quoted_status_id  retweet_count  \
# 0                    NaN      1.405553e+18              4
# 1                    NaN               NaN            210
# 2                    NaN               NaN             70
# 3           1.405563e+18               NaN              2
# 4                    NaN               NaN              8
#
#   quoted_status_id_str                   id in_reply_to_screen_name  \
# 0  1405552832208683011  1405918729045692419                     NaN
# 1                  NaN  1405647699483967493                     NaN
# 2                  NaN  1405586524066881541                     NaN
# 3                  NaN  1405564371913392133                 TpoM6oH
# 4                  NaN  1405552832208683011                     NaN
#
#    in_reply_to_user_id  user author
# 0                  NaN  code   code
# 1                  NaN  code   code
# 2                  NaN  code   code
# 3          243794902.0  code   code
# 4                  NaN  code   code

# %%
df1.to_csv('tweetspreadsheet.csv', index=False)

# %%
df1_saved_file = pd.read_csv('tweetspreadsheet.csv')
df1_saved_file
# Out:
#                                       source_url               id_str  \
# 0                     https://prod1.sprinklr.com  1405918729045692419
# 1                             https://buffer.com  1405647699483967493
# 2   https://about.twitter.com/products/tweetdeck  1405586524066881541
# 3   https://about.twitter.com/products/tweetdeck  1405564371913392133
# 4                             https://buffer.com  1405552832208683011
# 5                             https://buffer.com  1405284556693856256
# 6   https://about.twitter.com/products/tweetdeck  1405256932726697991
# 7                             https://buffer.com  1405210223627935750
# 8                             https://buffer.com  1405190182966640641
# 9                             https://buffer.com  1404923676605157376
# 10  https://about.twitter.com/products/tweetdeck  1404884676305588225
# 11                            https://buffer.com  1404865795268780038
# 12                            https://buffer.com  1404827556411588615
# 13                            https://buffer.com  1404559526431543301
# 14  https://about.twitter.com/products/tweetdeck  1404523914470957061
# 15  https://about.twitter.com/products/tweetdeck  1404514979194228747
# 16                            https://buffer.com  1404503914305802243
# 17                            https://buffer.com  1404455568245469185
# 18  https://about.twitter.com/products/tweetdeck  1403743811453390848
# 19                            https://buffer.com  1403463051198803979
#
#                  source                                               text  \
# 0   Sprinklr Publishing  Missed the livestream? You can now catch it on...
# 1                Buffer  RT @LeoKac333: Check out my VSCode extension -...
# 2             TweetDeck  RT @pythonvscode: And the June release of the ...
# 3             TweetDeck  @TpoM6oH Yup, it's a new feature! Read more in...
# 4                Buffer  🍿 We're going live in just a few mins with @su...
# 5                Buffer  RT @mattbierner: Today's @code setting: sugges...
# 6             TweetDeck  RT @yaojinyang: Welcome to May’s updates on VS...
# 7                Buffer  RT @freeCodeCamp: Have you heard? You can now ...
# 8                Buffer  RT @mattbierner: Today's @code tip: terminal t...
# 9                Buffer  RT @DynamicWebPaige: Have you ever tried @code...
# 10            TweetDeck  @marcduiker @suzmue CC: @anthonypjshaw Gopher ...
# 11               Buffer  RT @pythonvscode: The June release for the #ju...
# 12               Buffer  💬 What's so special about #Golang? And how can...
# 13               Buffer  RT @GarvNanwani: @code tip -\n\nNormally when ...
# 14            TweetDeck                    @n1k0 👀 https://t.co/PJyj1WayGk
# 15            TweetDeck  Use Remote Repositories in VS Code to browse a...
# 16               Buffer  RT @K8sArchitect: Learn to debug Go microservi...
# 17               Buffer  RT @Tyriar: .@MeganRogge_ and myself are about...
# 18            TweetDeck  RT @github: You can now browse or even make ed...
# 19               Buffer  RT @davidpine7: 💯 The @code extension API was ...
#
#     favorite_count lang  in_reply_to_status_id_str  in_reply_to_user_id_str  \
# 0               35   en                        NaN                      NaN
# 1                0   en                        NaN                      NaN
# 2                0   en                        NaN                      NaN
# 3               25   en               1.405563e+18              243794902.0
# 4               36   en                        NaN                      NaN
# 5                0   en                        NaN                      NaN
# 6                0   en                        NaN                      NaN
# 7                0   en                        NaN                      NaN
# 8                0   en                        NaN                      NaN
# 9                0   en                        NaN                      NaN
# 10               2   cy               1.404828e+18               28189006.0
# 11               0   en                        NaN                      NaN
# 12              63   en                        NaN                      NaN
# 13               0   en                        NaN                      NaN
# 14              11  und               1.404521e+18                6619162.0
# 15             372   en                        NaN                      NaN
# 16               0   en                        NaN                      NaN
# 17               0   en                        NaN                      NaN
# 18               0   en                        NaN                      NaN
# 19               0   en                        NaN                      NaN
#
#     in_reply_to_status_id  quoted_status_id  retweet_count  \
# 0                     NaN      1.405553e+18              4
# 1                     NaN               NaN            210
# 2                     NaN               NaN             70
# 3            1.405563e+18               NaN              2
# 4                     NaN               NaN              8
# 5                     NaN               NaN             24
# 6                     NaN               NaN             35
# 7                     NaN               NaN             95
# 8                     NaN               NaN             21
# 9                     NaN      1.404796e+18             94
# 10           1.404828e+18               NaN              0
# 11                    NaN               NaN             26
# 12                    NaN               NaN             13
# 13                    NaN               NaN             46
# 14           1.404521e+18               NaN              1
# 15                    NaN               NaN             94
# 16                    NaN               NaN             19
# 17                    NaN               NaN             38
# 18                    NaN               NaN            933
# 19                    NaN               NaN              6
#
#     quoted_status_id_str                   id in_reply_to_screen_name  \
# 0           1.405553e+18  1405918729045692419                     NaN
# 1                    NaN  1405647699483967493                     NaN
# 2                    NaN  1405586524066881541                     NaN
# 3                    NaN  1405564371913392133                 TpoM6oH
# 4                    NaN  1405552832208683011                     NaN
# 5                    NaN  1405284556693856256                     NaN
# 6                    NaN  1405256932726697991                     NaN
# 7                    NaN  1405210223627935750                     NaN
# 8                    NaN  1405190182966640641                     NaN
# 9           1.404796e+18  1404923676605157376                     NaN
# 10                   NaN  1404884676305588225              marcduiker
# 11                   NaN  1404865795268780038                     NaN
# 12                   NaN  1404827556411588615                     NaN
# 13                   NaN  1404559526431543301                     NaN
# 14                   NaN  1404523914470957061                    n1k0
# 15                   NaN  1404514979194228747                     NaN
# 16                   NaN  1404503914305802243                     NaN
# 17                   NaN  1404455568245469185                     NaN
# 18                   NaN  1403743811453390848                     NaN
# 19                   NaN  1403463051198803979                     NaN
#
#     in_reply_to_user_id  user author
# 0                   NaN  code   code
# 1                   NaN  code   code
# 2                   NaN  code   code
# 3           243794902.0  code   code
# 4                   NaN  code   code
# 5                   NaN  code   code
# 6                   NaN  code   code
# 7                   NaN  code   code
# 8                   NaN  code   code
# 9                   NaN  code   code
# 10           28189006.0  code   code
# 11                  NaN  code   code
# 12                  NaN  code   code
# 13                  NaN  code   code
# 14            6619162.0  code   code
# 15                  NaN  code   code
# 16                  NaN  code   code
# 17                  NaN  code   code
# 18                  NaN  code   code
# 19                  NaN  code   code
