# %%
# !pip install datetime

# %%
import tweepy #used to work with Twitter's API
import webbrowser
import time
import datetime 
import pandas as pd

# %%
consumer_key = "jzn0NU9EviCRRbONbUXX9a8VN" #pulled from developer account for Twitter
consumer_secret = "ULsKu9BjBPmZ3yY5NdS6EXUhGBNWKUWxtwKqFktBeqsOq1Y3ZQ" #pulled from developer account for Twitter
#key and secret is generated by Twitter developer account

# %%
callback_uri = 'oob'#url

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri) #authorization to pull data from Twitter's API
redirect_url = auth.get_authorization_url() 
print(redirect_url)
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=En13QwAAAAABQdBPAAABehospog

# %%
webbrowser.open(redirect_url)
# Out:
# True

# %%
user_pint_input = input("What's the pin value? ") #this is based upon Twitter Developer account
#Pin is generated new everytime this cell is run
# Out:
# What's the pin value? 2838638

# %%
auth.get_access_token(user_pint_input)
# Out:
# ('781482721-6928Gtnj95bK82PW3fYDxHFvU5T4l3SPI4VVF1X2',
#  'fTxclLJ4oxEmqshRhSbBibGoUiNq1l6941C0VyREdTf41')

# %%
print(auth.access_token, auth.access_token_secret)
# Out:
# 781482721-6928Gtnj95bK82PW3fYDxHFvU5T4l3SPI4VVF1X2 fTxclLJ4oxEmqshRhSbBibGoUiNq1l6941C0VyREdTf41

# %%
api = tweepy.API(auth)

# %%
# username = "code"
# startDate = datetime.datetime(2021, 6, 1, 0, 0, 0)
# endDate =   datetime.datetime(2021, 6, 15, 0, 0, 0)

# %%
# tweets = []
# tmpTweets = api.user_timeline(username)
# for tweet in tmpTweets:
#     if tweet.created_at < endDate and tweet.created_at > startDate:
#         tweets.append(tweet)

# %%
# while (tmpTweets[-1].created_at > startDate):
#     print("Last Tweet @", tmpTweets[-1].created_at, " - fetching some more")
#     print("ID TWEET: " + str(tweet.id))
#     tmpTweets = api.user_timeline(username, max_id = tmpTweets[-1].id)
#     for tweet in tmpTweets:
#         if tweet.created_at < endDate and tweet.created_at > startDate:
#             tweets.append(tweet)

# %%
# workbook = xlsxwriter.Workbook(username + ".xlsx")
# worksheet = workbook.add_worksheet()
# row = 0
# for tweet in tweets:
#     worksheet.write_string(row, 0, str(tweet.id))
#     worksheet.write_string(row, 1, str(tweet.created_at))
#     worksheet.write(row, 2, tweet.text)
#     worksheet.write_string(row, 3, str(tweet.in_reply_to_status_id))
#     row += 1

# workbook.close()
# print("Excel file ready")

# %%
# # fetching the statuses
# statuses = api.home_timeline()
# print(statuses)

# %%
# printing the screen names of each status
#for status in statuses:
    #print(status.user.screen_name)

# %%
def extract_timeline_as_df(timeline_list):
    columns = set()
    allowed_types = [str, int]
    tweets_data = []
    for status in timeline_list:
        status_dict = dict(vars(status))
        keys = status_dict.keys()
        single_tweet_data = {"user": status.user.screen_name, "author": status.author.screen_name}
        for k in keys:
            try:
                v_type = type(status_dict[k])
            except:
                v_type = None
            if v_type != None:
                if v_type in allowed_types:
                    single_tweet_data[k] = status_dict[k]
                    columns.add(k)
        tweets_data.append(single_tweet_data)


    header_cols = list(columns)
    header_cols.append("user")
    header_cols.append('author')
    df = pd.DataFrame(tweets_data, columns=header_cols)
    return df

# %%
screen_name = "code" #pulls data from Visual Studio Code's twitter page https://twitter.com/code
user = api.get_user(screen_name)
user_timeline = user.timeline()
#range_oftweets = api.search([2021-6-10][1405284556693856256])
#df1 = extract_timeline_as_df(range_oftweets)
df1 = extract_timeline_as_df(user_timeline)
df1.head()
# startDate = datetime.datetime(2021, 6, 1)
# endDate =   datetime.datetime(2021, 6, 10)
# Out:
#   in_reply_to_user_id_str                                    source_url  \
# 0                     NaN                            https://buffer.com
# 1                     NaN  https://about.twitter.com/products/tweetdeck
# 2                     NaN                            https://buffer.com
# 3                     NaN                            https://buffer.com
# 4                     NaN                            https://buffer.com
#
#    favorite_count  retweet_count                   id  quoted_status_id  \
# 0               0             24  1405284556693856256               NaN
# 1               0             31  1405256932726697991               NaN
# 2               0             91  1405210223627935750               NaN
# 3               0             20  1405190182966640641               NaN
# 4               0             91  1404923676605157376      1.404796e+18
#
#                 id_str in_reply_to_status_id_str  \
# ...

# %%
# for tweet in tweepy.Cursor(api.user_timeline, screen_name="@code", since=startDate, until=endDate).items():
#     user = api.get_status(tweet.id)
#     # fetching the created_at attribute
#     created_at = status.created_at 
#     print("The status was created at : " + str(created_at))
#     print("ID TWEET: " + str(tweet.id))
#     break

# %%
range_oftweets = api.search([2021-6-10])
print(range_oftweets)
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000024843802610>, _json={'created_at': 'Thu Jun 17 13:33:07 +0000 2021', 'id': 1405518872044883976, 'id_str': '1405518872044883976', 'text': 'RT @CorteSupremaJ: Ley de garantías (996 de 2005) no solo prohíbe contratar nuevo personal, sino despedir el existente. Impide intimidación…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'CorteSupremaJ', 'name': 'Corte Suprema de Justicia', 'id': 208901797, 'id_str': '208901797', 'indices': [3, 17]}], 'urls': []}, 'metadata': {'iso_language_code': 'es', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3294309927, 'id_str': '3294309927', 'name': 'Alfonso Plata V', 'screen_name': 'alfonso_platav', 'locatio
# ...

# %%
# tweets = []
# tmpTweets = user.timeline()
# for tweet in tmpTweets:
#     if tweet.created_at < endDate and tweet.created_at > startDate:
#         tweets.append(tweet)
#     print(tweet)

# %%
# df1 = extract_timeline_as_df(api.home_timeline)
# df1.head()

# %%
# while (tmpTweets[-1].created_at > startDate):
#     tmpTweets = api.user_timeline(username, max_id = tmpTweets[-1].id)
#     for tweet in tmpTweets:
#         if tweet.created_at < endDate and tweet.created_at > startDate:
#             tweets.append(tweet)
